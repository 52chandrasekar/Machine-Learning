# %% [markdown]
# #Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA ONBORDING

# %%
df=pd.read_csv('BREAST CANCER.csv')

# %%
# DATAFRAME
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
#EDA

# %%
df_copy=df.copy()

# %%
df.shape
# Out:
# (569, 33)

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [5 rows x 33 columns]

# %%
df.iloc[100:201]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 100  862717         M       13.610         24.98           88.05      582.7
# 101  862722         B        6.981         13.43           43.79      143.5
# 102  862965         B       12.180         20.52           77.22      458.7
# 103  862980         B        9.876         19.40           63.95      298.3
# 104  862989         B       10.490         19.29           67.41      336.1
# ..      ...       ...          ...           ...             ...        ...
# 196  875938         M       13.770         22.29           90.63      588.9
# 197  877159         M       18.080         21.84          117.40     1024.0
# 198  877486         M       19.180         22.49          127.50     1148.0
# 199  877500         M       14.450         20.22           94.49      642.7
# 200  877501         B       12.230         19.56           78.54      461.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 100          0.09488           0.08511         0.08625              0.04489
# 101          0.11700           0.07568         0.00000              0.00000
# 102          0.08013           0.04038         0.02383              0.01770
# 103          0.10050           0.09697         0.06154              0.03029
# 104          0.09989           0.08578         0.02995              0.01201
# ..               ...               ...             ...                  ...
# 196          0.12000           0.12670         0.13850              0.06526
# 197          0.07371           0.08642         0.11030              0.05778
# 198          0.08523           0.14280         0.11140              0.06772
# 199          0.09872           0.12060         0.11800              0.05980
# 200          0.09586           0.08087         0.04187              0.04107
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 100  ...          35.27           108.60       906.5           0.12650
# 101  ...          19.54            50.41       185.2           0.15840
# 102  ...          32.84            84.58       547.8           0.11230
# 103  ...          26.83            72.22       361.2           0.15590
# 104  ...          23.31            74.22       402.8           0.12190
# ..   ...            ...              ...         ...               ...
# 196  ...          34.01           111.60       806.9           0.17370
# 197  ...          24.70           129.10      1228.0           0.08822
# 198  ...          32.06           166.40      1688.0           0.13220
# 199  ...          30.12           117.90      1044.0           0.15520
# 200  ...          28.36            92.15       638.4           0.14290
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 100            0.19430          0.31690               0.11840          0.2651
# 101            0.12020          0.00000               0.00000          0.2932
# 102            0.08862          0.11450               0.07431          0.2694
# 103            0.23020          0.26440               0.09749          0.2622
# 104            0.14860          0.07987               0.03203          0.2826
# ..                 ...              ...                   ...             ...
# 196            0.31220          0.38090               0.16730          0.3080
# 197            0.19630          0.25350               0.09181          0.2369
# 198            0.56010          0.38650               0.17080          0.3193
# 199            0.40560          0.49670               0.18380          0.4753
# 200            0.20420          0.13770               0.10800          0.2668
#
#      fractal_dimension_worst  Unnamed: 32
# 100                  0.07397          NaN
# 101                  0.09382          NaN
# 102                  0.06878          NaN
# 103                  0.08490          NaN
# 104                  0.07552          NaN
# ..                       ...          ...
# 196                  0.09333          NaN
# 197                  0.06558          NaN
# 198                  0.09221          NaN
# 199                  0.10130          NaN
# 200                  0.08174          NaN
#
# [101 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.describe().T.style.background_gradient(sns.color_palette("light:#5A9", as_cmap=True))
# Out:
# <style type="text/css">
# #T_3c3fb_row0_col0, #T_3c3fb_row0_col1, #T_3c3fb_row0_col2, #T_3c3fb_row0_col3, #T_3c3fb_row0_col4, #T_3c3fb_row0_col5, #T_3c3fb_row0_col6, #T_3c3fb_row0_col7, #T_3c3fb_row1_col0, #T_3c3fb_row2_col0, #T_3c3fb_row3_col0, #T_3c3fb_row4_col0, #T_3c3fb_row5_col0, #T_3c3fb_row6_col0, #T_3c3fb_row7_col0, #T_3c3fb_row8_col0, #T_3c3fb_row9_col0, #T_3c3fb_row10_col0, #T_3c3fb_row11_col0, #T_3c3fb_row12_col0, #T_3c3fb_row13_col0, #T_3c3fb_row14_col0, #T_3c3fb_row15_col0, #T_3c3fb_row16_col0, #T_3c3fb_row17_col0, #T_3c3fb_row18_col0, #T_3c3fb_row19_col0, #T_3c3fb_row20_col0, #T_3c3fb_row21_col0, #T_3c3fb_row22_col0, #T_3c3fb_row23_col0, #T_3c3fb_row24_col0, #T_3c3fb_row25_col0, #T_3c3fb_row26_col0, #T_3c3fb_row27_col0, #T_3c3fb_row28_col0, #T_3c3fb_row29_col0, #T_3c3fb_row30_col0 {
#   background-color: #55aa99;
#   color: #f1f1f1;
# }
# #T_3c3fb_row1_col1, #T_3c3fb_row1_col2, #T_3c3fb_row1_col3, #T_3c3fb_row1_col4, #T_3c3fb_row1_col5, #T_3c3fb_row1_col6, #T_3c3fb_row1_col7, #T_3c3fb_row2_col1, #T_3c3fb_row2_col2, #T_3c3fb_row2_col3, #T_3c3fb_row2_col4, #T_3c3fb_row2_col5, #T_3c3fb_row2_col6, #T_3c3fb_row2_col7, #T_3c3fb_row3_col1, #T_3c3fb_row3_col2, #T_3c3fb_row3_col3, #T_3c3fb_row3_col4, #T_3c3fb_row3_col5, #T_3c3fb_row3_col6, #T_3c3fb_row3_col7, #T_3c3fb_row4_col1, #T_3c3fb_row4_col2, #T_3c3fb_row4_col4, #T_3c3fb_row4_col5, #T_3c3fb_row4_col6, #T_3c3fb_row4_col7, #T_3c3fb_row5_col1, #T_3c3fb_row5_col2, #T_3c3fb_row5_col3, #T_3c3fb_row5_col4, #T_3c3fb_row5_col5, #T_3c3fb_row5_col6, #T_3c3fb_row5_col7, #T_3c3fb_row6_col1, #T_3c3fb_row6_col2, #T_3c3fb_row6_col3, #T_3c3fb_row6_col4, #T_3c3fb_row6_col5, #T_3c3fb_row6_col6, #T_3c3fb_row6_col7, #T_3c3fb_row7_col1, #T_3c3fb_row7_col2, #T_3c3fb_row7_col3, #T_3c3fb_row7_col4, #T_3c3fb_row7_col5, #T_3c3fb_row7_col6, #T_3c3fb_row7_col7, #T_3c3fb_row8_col1, #T_3c3fb_row8_col2, #T_3c3fb_row8_col3, #T_3c3fb_row8_col4, #T_3c3fb_row8_col5, #T_3c3fb_row8_col6, #T_3c3fb_row8_col7, #T_3c3fb_row9_col1, #T_3c3fb_row9_col2, #T_3c3fb_row9_col3, #T_3c3fb_row9_col4, #T_3c3fb_row9_col5, #T_3c3fb_row9_col6, #T_3c3fb_row9_col7, #T_3c3fb_row10_col1, #T_3c3fb_row10_col2, #T_3c3fb_row10_col3, #T_3c3fb_row10_col4, #T_3c3fb_row10_col5, #T_3c3fb_row10_col6, #T_3c3fb_row10_col7, #T_3c3fb_row11_col1, #T_3c3fb_row11_col2, #T_3c3fb_row11_col3, #T_3c3fb_row11_col4, #T_3c3fb_row11_col5, #T_3c3fb_row11_col6, #T_3c3fb_row11_col7, #T_3c3fb_row12_col1, #T_3c3fb_row12_col2, #T_3c3fb_row12_col3, #T_3c3fb_row12_col4, #T_3c3fb_row12_col5, #T_3c3fb_row12_col6, #T_3c3fb_row12_col7, #T_3c3fb_row13_col1, #T_3c3fb_row13_col2, #T_3c3fb_row13_col3, #T_3c3fb_row13_col4, #T_3c3fb_row13_col5, #T_3c3fb_row13_col6, #T_3c3fb_row13_col7, #T_3c3fb_row14_col1, #T_3c3fb_row14_col2, #T_3c3fb_row14_col3, #T_3c3fb_row14_col4, #T_3c3fb_row14_col5, #T_3c3fb_row14_col6, #T_3c3fb_row14_col7, #T_3c3fb_row15_col1, #T_3c3fb_row15_col2, #T_3c3fb_row15_col3, #T_3c3fb_row15_col4, #T_3c3fb_row15_col5, #T_3c3fb_row15_col6, #T_3c3fb_row15_col7, #T_3c3fb_row16_col1, #T_3c3fb_row16_col2, #T_3c3fb_row16_col3, #T_3c3fb_row16_col4, #T_3c3fb_row16_col5, #T_3c3fb_row16_col6, #T_3c3fb_row16_col7, #T_3c3fb_row17_col1, #T_3c3fb_row17_col2, #T_3c3fb_row17_col3, #T_3c3fb_row17_col4, #T_3c3fb_row17_col5, #T_3c3fb_row17_col6, #T_3c3fb_row17_col7, #T_3c3fb_row18_col1, #T_3c3fb_row18_col2, #T_3c3fb_row18_col3, #T_3c3fb_row18_col4, #T_3c3fb_row18_col5, #T_3c3fb_row18_col6, #T_3c3fb_row18_col7, #T_3c3fb_row19_col1, #T_3c3fb_row19_col2, #T_3c3fb_row19_col3, #T_3c3fb_row19_col4, #T_3c3fb_row19_col5, #T_3c3fb_row19_col6, #T_3c3fb_row19_col7, #T_3c3fb_row20_col1, #T_3c3fb_row20_col2, #T_3c3fb_row20_col3, #T_3c3fb_row20_col4, #T_3c3fb_row20_col5, #T_3c3fb_row20_col6, #T_3c3fb_row20_col7, #T_3c3fb_row21_col1, #T_3c3fb_row21_col2, #T_3c3fb_row21_col3, #T_3c3fb_row21_col4, #T_3c3fb_row21_col5, #T_3c3fb_row21_col6, #T_3c3fb_row21_col7, #T_3c3fb_row22_col1, #T_3c3fb_row22_col2, #T_3c3fb_row22_col3, #T_3c3fb_row22_col4, #T_3c3fb_row22_col5, #T_3c3fb_row22_col6, #T_3c3fb_row22_col7, #T_3c3fb_row23_col1, #T_3c3fb_row23_col2, #T_3c3fb_row23_col3, #T_3c3fb_row23_col4, #T_3c3fb_row23_col5, #T_3c3fb_row23_col6, #T_3c3fb_row23_col7, #T_3c3fb_row24_col1, #T_3c3fb_row24_col2, #T_3c3fb_row24_col4, #T_3c3fb_row24_col5, #T_3c3fb_row24_col6, #T_3c3fb_row24_col7, #T_3c3fb_row25_col1, #T_3c3fb_row25_col2, #T_3c3fb_row25_col3, #T_3c3fb_row25_col4, #T_3c3fb_row25_col5, #T_3c3fb_row25_col6, #T_3c3fb_row25_col7, #T_3c3fb_row26_col1, #T_3c3fb_row26_col2, #T_3c3fb_row26_col3, #T_3c3fb_row26_col4, #T_3c3fb_row26_col5, #T_3c3fb_row26_col6, #T_3c3fb_row26_col7, #T_3c3fb_row27_col1, #T_3c3fb_row27_col2, #T_3c3fb_row27_col3, #T_3c3fb_row27_col4, #T_3c3fb_row27_col5, #T_3c3fb_row27_col6, #T_3c3fb_row27_col7, #T_3c3fb_row28_col1, #T_3c3fb_row28_col2, #T_3c3fb_row28_col3, #T_3c3fb_row28_col4, #T_3c3fb_row28_col5, #T_3c3fb_row28_col6, #T_3c3fb_ ...
#   background-color: #ebf2f0;
#   color: #000000;
# }
# #T_3c3fb_row4_col3 {
#   background-color: #e9f1ef;
#   color: #000000;
# }
# #T_3c3fb_row24_col3 {
#   background-color: #e8f1ef;
#   color: #000000;
# }
# #T_3c3fb_row31_col1, #T_3c3fb_row31_col2, #T_3c3fb_row31_col3, #T_3c3fb_row31_col4, #T_3c3fb_row31_col5, #T_3c3fb_row31_col6, #T_3c3fb_row31_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3c3fb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c3fb_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_3c3fb_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_3c3fb_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_3c3fb_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_3c3fb_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_3c3fb_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_3c3fb_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_3c3fb_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c3fb_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_3c3fb_row0_col0" class="data row0 col0" >569.000000</td>
#       <td id="T_3c3fb_row0_col1" class="data row0 col1" >30371831.432337</td>
#       <td id="T_3c3fb_row0_col2" class="data row0 col2" >125020585.612224</td>
#       <td id="T_3c3fb_row0_col3" class="data row0 col3" >8670.000000</td>
#       <td id="T_3c3fb_row0_col4" class="data row0 col4" >869218.000000</td>
#       <td id="T_3c3fb_row0_col5" class="data row0 col5" >906024.000000</td>
#       <td id="T_3c3fb_row0_col6" class="data row0 col6" >8813129.000000</td>
#       <td id="T_3c3fb_row0_col7" class="data row0 col7" >911320502.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3c3fb_level0_row1" class="row_heading level0 row1" >radius_mean</th>
#       <td id="T_3c3fb_row1_col0" class="data row1 col0" >569.000000</td>
#       <td id="T_3c3fb_row1_col1" class="data row1 col1" >14.127292</td>
#       <td id="T_3c3fb_row1_col2" class="data row1 col2" >3.524049</td>
#       <td id="T_3c3fb_row1_col3" class="data row1 col3" >6.981000</td>
#       <td id="T_3c3fb_row1_col4" class="data row1 col4" >11.700000</td>
#       <td id="T_3c3fb_row1_col5" class="data row1 col5" >13.370000</td>
#       <td id="T_3c3fb_row1_col6" class="data row1 col6" >15.780000</td>
#       <td id="T_3c3fb_row1_col7" class="data row1 col7" >28.110000</td>
#     </tr>
#     <tr>
#       <th id="T_3c3fb_level0_row2" class="row_heading level0 row2" >texture_mean</th>
#       <td id="T_3c3fb_row2_col0" class="data row2 col0" >569.000000</td>
#       <td id="T_3c3fb_row2_col1" class="data row2 col1" >19.289649</td>
#       <td id="T_3c3fb_row2_col2" class="dat

# %% [markdown]
# #visualization

# %%
sns.countplot(x='diagnosis',data=df)
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-15-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
texture=df[['texture_mean','texture_se','texture_worst','diagnosis']]
sns.pairplot(texture,hue='diagnosis')

# %%
smoothness=df[['smoothness_mean','smoothness_se','smoothness_worst','diagnosis']]
sns.pairplot(smoothness,hue='diagnosis')

# %%
perimeter=df[['perimeter_mean','perimeter_se','perimeter_worst','diagnosis']]
sns.pairplot(perimeter,hue='diagnosis')

# %%
fractal=df[['fractal_dimension_mean','fractal_dimension_worst','fractal_dimension_se','diagnosis']]
sns.pairplot(fractal,hue='diagnosis')

# %%
concavity=df[['concavity_worst','concavity_se','concavity_mean','diagnosis']]
sns.pairplot(concavity,hue='diagnosis')

# %%
concave=df[['concave points_mean','concave points_se','concave points_worst','diagnosis']]
sns.pairplot(concave,hue='diagnosis')

# %%
compactness=df[['compactness_mean','compactness_se','compactness_worst','diagnosis']]
sns.pairplot(compactness,hue='diagnosis')

# %%
radius=df[['radius_mean','radius_se','radius_worst','diagnosis']]
sns.pairplot(radius,hue='diagnosis')

# %%
area=df[['area_mean','area_se','area_worst','diagnosis']]
sns.pairplot(area,hue='diagnosis')

# %% [markdown]
# #DATA CLEANING

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df.drop(columns='Unnamed: 32',inplace=True)

# %%
df.drop(columns='id',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# # X and y split

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
y=df['diagnosis']
x=df.drop('diagnosis',axis=1)

# %% [markdown]
# # Labuel encoding

# %%
from sklearn.preprocessing import LabelEncoder
lbe=LabelEncoder()
y=lbe.fit_transform(y)

# %% [markdown]
# # TRAIN AND TEST

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=124)

# %% [markdown]
# # KNeighborsClassifier(KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
k=3
knn=KNeighborsClassifier(n_neighbors=k)
# train
knn.fit(x_train,y_train)
# predict
y_pred_knn=knn.predict(x_test)

# %%
# Evaluation KNN

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm_knn=confusion_matrix(y_test,y_pred_knn)
acc_knn=accuracy_score(y_test,y_pred_knn)*100
cr=classification_report(y_test,y_pred_knn)
print('confusion_matrix:',cm_knn)
print('accuracy_score:',acc_knn)
print('classification_report',cr)
# ERROR RATE AND CLASSIFICATION REPORT
print("Misclassification error rate:",round(np.mean(y_pred_knn!=y_test),3))
print(classification_report(y_test,y_pred_knn))
# Out:
# confusion_matrix: [[98  4]
#  [10 59]]
# accuracy_score: 91.81286549707602
# classification_report               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       102
#            1       0.94      0.86      0.89        69
#
#     accuracy                           0.92       171
#    macro avg       0.92      0.91      0.91       171
# weighted avg       0.92      0.92      0.92       171
#
# Misclassification error rate: 0.082
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       102
#            1       0.94      0.86      0.89        69
#
#     accuracy                           0.92       171
#    macro avg       0.92      0.91      0.91       171
# weighted avg       0.92      0.92      0.92       171

# %% [markdown]
# ##Choosing ‘k’ by elbow **method**

# %%
# ERROR VALUE
error_value=[]
for i in range(1,60):
  knn_i=KNeighborsClassifier(n_neighbors=i)
  knn_i.fit(x_train,y_train)
  y_pred_knn_i=knn_i.predict(x_test)
  error_value.append(np.mean(y_pred_knn_i!=y_test))

# %%
# PLOT FOR ERROR VALUE
plt.plot(range(1,60),error_value,color='blue',linestyle='dashed',marker='o',markerfacecolor='red', markersize=8)
plt.title('error_values vs k value')
plt.xlabel('k')
plt.ylabel("error_value(miscalssification)")
# Out:
# Text(0, 0.5, 'error_value(miscalssification)')

# %% [markdown]
# # Support Vector Regression (SVR)

# %%
from sklearn.svm import SVC
# create the SVM classifier
svm = SVC()
# Train the classifier on the training data
svm.fit(x_train, y_train)
# Make predictions on the testing data
y_pred_svm= svm.predict(x_test)

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_svm= accuracy_score(y_test, y_pred_svm)*100
print(f"Accuracy: {accuracy_svm}")
cm_svm= confusion_matrix(y_test,y_pred_svm)
print('Confusion',cm_svm)
# ERROR RATE AND CLASSIFICATION REPORT
print("Misclassification error rate:",round(np.mean(y_pred_svm!=y_test),3))
print(classification_report(y_test,y_pred_svm))
# Out:
# Accuracy: 90.05847953216374
# Confusion [[101   1]
#  [ 16  53]]
# Misclassification error rate: 0.099
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       102
#            1       0.98      0.77      0.86        69
#
#     accuracy                           0.90       171
#    macro avg       0.92      0.88      0.89       171
# weighted avg       0.91      0.90      0.90       171

# %% [markdown]
# #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
#Logistic Regression model
lg=LogisticRegression()
# Train the model on the training data
lg.fit(x_train,y_train)
# Make predictions on the testing data
y_pred_lg=lg.predict(x_test)
# Evaluate the model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Evaluate the model
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score,precision_score,recall_score,balanced_accuracy_score
cm_lg = confusion_matrix(y_test,y_pred_lg)
print('Confusion',cm_lg)
accuracy_lg= accuracy_score(y_test,y_pred_lg)*100
print('Accuracy',accuracy_lg)
# ERROR RATE AND CLASSIFICATION REPORT
print("Misclassification error rate:",round(np.mean(y_pred_lg!=y_test),3))
print(classification_report(y_test,y_pred_lg))
# Out:
# Confusion [[96  6]
#  [ 5 64]]
# Accuracy 93.56725146198829
# Misclassification error rate: 0.064
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       102
#            1       0.91      0.93      0.92        69
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.93      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %% [markdown]
# #Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
# Multinomial Naive Bayes classifier
mnb=MultinomialNB()
# Train the model on the training data
mnb.fit(x_train,y_train)
# Make predictions on the testing data
y_pred_nb=mnb.predict(x_test)
# Evaluate the model
from sklearn.metrics import confusion_matrix,accuracy_score
cm_nb= confusion_matrix(y_test,y_pred_nb)
print('Confusion',cm_nb)
accuracy_nb= accuracy_score(y_test,y_pred_nb)*100
print('Accuracy',accuracy_nb)
# Out:
# Confusion [[97  5]
#  [19 50]]
# Accuracy 85.96491228070175

# %%
# ERROR RATE AND CLASSIFICATION REPORT
print("Misclassification error rate:",round(np.mean(y_pred_nb!=y_test),3))
print(classification_report(y_test,y_pred_nb))
# Out:
# Misclassification error rate: 0.14
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89       102
#            1       0.91      0.72      0.81        69
#
#     accuracy                           0.86       171
#    macro avg       0.87      0.84      0.85       171
# weighted avg       0.87      0.86      0.86       171

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
# train
dt.fit(x_train,y_train)
# predit
y_pred_dt=dt.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm_dt= confusion_matrix(y_test,y_pred_dt)
print('Confusion',cm_dt)
accuracy_dt= accuracy_score(y_test,y_pred_dt)*100
print('Accuracy',accuracy_dt)
# ERROR RATE AND CLASSIFICATION REPORT
print("Misclassification error rate:",round(np.mean(y_pred_dt!=y_test),3))
print(classification_report(y_test,y_pred_dt))
# Out:
# Confusion [[94  8]
#  [ 7 62]]
# Accuracy 91.22807017543859
# Misclassification error rate: 0.088
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       102
#            1       0.89      0.90      0.89        69
#
#     accuracy                           0.91       171
#    macro avg       0.91      0.91      0.91       171
# weighted avg       0.91      0.91      0.91       171

# %% [markdown]
# # Evaluation visualization

# %% [markdown]
# ## KNN

# %%
from mlxtend.plotting import plot_confusion_matrix
plot_confusion_matrix(cm_knn)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ## SVM

# %%
# confusion matrix plot
from mlxtend.plotting import plot_confusion_matrix
plot_confusion_matrix(cm_svm)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ##Logistic Regression

# %%
# confusion matrix plot
from mlxtend.plotting import plot_confusion_matrix
plot_confusion_matrix(cm_lg)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ##Naive Bayes

# %%
# confusion matrix plot
from mlxtend.plotting import plot_confusion_matrix
plot_confusion_matrix(cm_nb)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ##Decision Tree

# %%
# confusion matrix plot
from mlxtend.plotting import plot_confusion_matrix
plot_confusion_matrix(cm_dt)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ## Model Evaluation data frame (using function)

# %%
def train_evaluation_model(model,x_train,y_train,x_test,y_test):
  model.fit(x_train,y_train)
  pred=model.predict(x_test)
  accuracy = accuracy_score(y_test, pred)
  f1 = f1_score(y_test, pred)
  precision = precision_score(y_test, pred)
  recall = recall_score(y_test, pred)
  balanced_accuracy = balanced_accuracy_score(y_test, pred)
  error_val=round(np.mean(pred!=y_test),3)
  ev_df=pd.DataFrame([[accuracy, f1, precision, recall, balanced_accuracy,error_val]],columns=('accuracy','f1','precision','recall','balanced_accuracy','error_value'))
  return ev_df

# %%
result=train_evaluation_model(lg,x_train,y_train,x_test,y_test)
dt_results = train_evaluation_model(dt,x_train, y_train, x_test, y_test)
knn_results = train_evaluation_model(knn,x_train, y_train, x_test, y_test)
nb_results = train_evaluation_model(mnb,x_train, y_train, x_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
result.index=['Logistic Regression']
dt_results.index=['decision tree']
result = result.append(dt_results)
knn_results.index=['K-Nearest Neighbors']
nb_results.index=['Naive Bayes']
result = result.append(knn_results)
result = result.append(nb_results)
# Out:
# <ipython-input-54-97d3832c0520>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(dt_results)
# <ipython-input-54-97d3832c0520>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(knn_results)
# <ipython-input-54-97d3832c0520>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(nb_results)

# %% [markdown]
# ## result visualization

# %%
result.sort_values(by='f1',ascending=False).style.background_gradient(sns.color_palette("Spectral", as_cmap=True))
# Out:
# <style type="text/css">
# #T_382c3_row0_col0, #T_382c3_row0_col1, #T_382c3_row0_col3, #T_382c3_row0_col4, #T_382c3_row2_col2, #T_382c3_row3_col5 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_382c3_row0_col2 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_382c3_row0_col5, #T_382c3_row3_col0, #T_382c3_row3_col1, #T_382c3_row3_col2, #T_382c3_row3_col3, #T_382c3_row3_col4 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_382c3_row1_col0 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_382c3_row1_col1 {
#   background-color: #459eb4;
#   color: #f1f1f1;
# }
# #T_382c3_row1_col2 {
#   background-color: #d23a4e;
#   color: #f1f1f1;
# }
# #T_382c3_row1_col3 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_382c3_row1_col4 {
#   background-color: #4ba4b1;
#   color: #f1f1f1;
# }
# #T_382c3_row1_col5 {
#   background-color: #e75948;
#   color: #f1f1f1;
# }
# #T_382c3_row2_col0 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_382c3_row2_col1 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_382c3_row2_col3 {
#   background-color: #cdeb9d;
#   color: #000000;
# }
# #T_382c3_row2_col4 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_382c3_row2_col5 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_382c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_382c3_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_382c3_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_382c3_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_382c3_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_382c3_level0_col4" class="col_heading level0 col4" >balanced_accuracy</th>
#       <th id="T_382c3_level0_col5" class="col_heading level0 col5" >error_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_382c3_level0_row0" class="row_heading level0 row0" >Logistic Regression</th>
#       <td id="T_382c3_row0_col0" class="data row0 col0" >0.935673</td>
#       <td id="T_382c3_row0_col1" class="data row0 col1" >0.920863</td>
#       <td id="T_382c3_row0_col2" class="data row0 col2" >0.914286</td>
#       <td id="T_382c3_row0_col3" class="data row0 col3" >0.927536</td>
#       <td id="T_382c3_row0_col4" class="data row0 col4" >0.934356</td>
#       <td id="T_382c3_row0_col5" class="data row0 col5" >0.064000</td>
#     </tr>
#     <tr>
#       <th id="T_382c3_level0_row1" class="row_heading level0 row1" >decision tree</th>
#       <td id="T_382c3_row1_col0" class="data row1 col0" >0.923977</td>
#       <td id="T_382c3_row1_col1" class="data row1 col1" >0.905109</td>
#       <td id="T_382c3_row1_col2" class="data row1 col2" >0.911765</td>
#       <td id="T_382c3_row1_col3" class="data row1 col3" >0.898551</td>
#       <td id="T_382c3_row1_col4" class="data row1 col4" >0.919864</td>
#       <td id="T_382c3_row1_col5" class="data row1 col5" >0.076000</td>
#     </tr>
#     <tr>
#       <th id="T_382c3_level0_row2" class="row_heading level0 row2" >K-Nearest Neighbors</th>
#       <td id="T_382c3_row2_col0" class="data row2 col0" >0.918129</td>
#       <td id="T_382c3_row2_col1" class="data row2 col1" >0.893939</td>
#       <td id="T_382c3_row2_col2" class="data row2 col2" >0.936508</td>
#       <td id="T_382c3_row2_col3" class="data row2 col3" >0.855072</td>
#       <td id="T_382c3_row2_col4" class="data row2 col4" >0.907928</td>
#       <td id="T_382c3_row2_col5" class="data row2 col5" >0.082000</td>
#     </tr>
#     <tr>
#       <th id="T_382c3_level0_row3" class="row_heading level0 row3" >Naive Bayes</th>
#       <td id="T_382c3_row3_col0" class="data row3 col0" >0.859649</td>
#       <td id="T_382c3_row3_col1" class="data row3 col1" >0.806452</td>
#       <td id="T_382c3_row3_col2" class="data row3 col2" >0.909091</td>
#       <td id="T_382c3_row3_col3" class="data row3 col3" >0.724638</td>
#       <td id="T_382c3_row3_col4" class="data row3 col4" >0.837809</td>
#       <td id="T_382c3_row3_col5" class="data row3 col5" >0.140000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Accurancy comparision of the classes
class_name = ('knn','svm','Logistic Regression','naive bayes','decision tree')
class_score=(acc_knn,accuracy_svm,accuracy_lg,accuracy_nb,accuracy_dt)
colors=('r','g','orange','b','pink')
plt.bar(class_name,class_score,color=colors)
plt.title(' Accurancy comparision of the classes')
plt.ylabel('Accurancy')
# Out:
# Text(0, 0.5, 'Accurancy')
